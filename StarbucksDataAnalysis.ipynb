# %% [markdown]
# # Data Science for All - Spring 2026
# ## Week 5 - Feb 4th 2026
# ### Prof. Reis

# %%
from google.colab import drive
import os

drive.mount("/content/drive",force_remount=True)
path="/content/drive/MyDrive/DataScienceSpring2026"
os.chdir(path)
# !ls
# Out:
# Mounted at /content/drive
# starbucks_drinkMenu_expanded.csv

# %%
import pandas as pd

df = pd.read_csv("starbucks_drinkMenu_expanded.csv")
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.columns # the column names or features
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        'Total Fat (g)', 'Trans Fat (g)', 'Saturated Fat (g)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Cholesterol (mg)', 'Dietary Fibre (g)',
#        'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)',
#        'Calcium (% DV)', 'Iron (% DV)', 'Caffeine (mg)'],
#       dtype='object')

# %%
df.shape # number of observations and number of columns (features)
# Out:
# (242, 18)

# %%
df.info() # this function (hence the ()) gives you the number of datapoints and their type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Beverage_category        242 non-null    object
#  1   Beverage                 242 non-null    object
#  2   Beverage_prep            242 non-null    object
#  3   Calories                 242 non-null    float64
#  4   Total Fat (g)            242 non-null    float64
#  5   Trans Fat (g)            242 non-null    float64
#  6   Saturated Fat (g)        242 non-null    float64
#  7   Sodium (mg)              242 non-null    int64
#  8   Total Carbohydrates (g)  242 non-null    int64
#  9   Cholesterol (mg)         242 non-null    int64
#  10  Dietary Fibre (g)        242 non-null    int64
#  11  Sugars (g)               242 non-null    int64
#  12  Protein (g)              242 non-null    float64
#  13  Vitamin A (% DV)         242 non-null    float64
# ...

# %%
df["Beverage"] # accessing a specific column in my table
# Out:
# 0                                     Brewed Coffee
# 1                                     Brewed Coffee
# 2                                     Brewed Coffee
# 3                                     Brewed Coffee
# 4                                       Caffè Latte
#                            ...
# 237    Strawberries & Crème (Without Whipped Cream)
# 238            Vanilla Bean (Without Whipped Cream)
# 239            Vanilla Bean (Without Whipped Cream)
# 240            Vanilla Bean (Without Whipped Cream)
# 241            Vanilla Bean (Without Whipped Cream)
# Name: Beverage, Length: 242, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=242, step=1)

# %%
df["Caffeine (mg)"].min()
# Out:
# 0.0

# %%
df["Caffeine (mg)"].max()
# Out:
# 410.0

# %%
df["Caffeine (mg)"].mean()
# Out:
# np.float64(89.52054794520548)

# %%
df["Caffeine (mg)"].var()
# Out:
# 4189.562649239669

# %%
df["Caffeine (mg)"].std()
# Out:
# 64.72683098406463

# %%
df.describe() # it provides a descriptive statistics table for the numerical values
# IMPOTANT!
# Out:
#          Calories  Total Fat (g)  Trans Fat (g)  Saturated Fat (g)  \
# count  242.000000     242.000000     242.000000         242.000000
# mean   193.871901       2.904959       1.307025           0.037603
# std    102.863303       2.944376       1.640259           0.071377
# min      0.000000       0.000000       0.000000           0.000000
# 25%    120.000000       0.200000       0.100000           0.000000
# 50%    185.000000       2.500000       0.500000           0.000000
# 75%    260.000000       4.500000       2.000000           0.100000
# max    510.000000      15.000000       9.000000           0.300000
#
#        Sodium (mg)  Total Carbohydrates (g)  Cholesterol (mg)  \
# count   242.000000               242.000000        242.000000
# mean      6.363636               128.884298         35.991736
# std       8.630257                82.303223         20.795186
# min       0.000000                 0.000000          0.000000
# ...

# %%
# Accessing multiple columns at the same time
df_partial = df[["Calories","Sugars (g)", "Cholesterol (mg)"]]
df_partial

# %%
# Accessing specific rows (or datapoints)

df.loc[0]

# %%
df.loc[[25,50]]

# %%
df.loc[[25,50],["Calories","Cholesterol (mg)"]]
# Out:
#     Calories  Cholesterol (mg)
# 25     280.0                54
# 50      80.0                12

# %%
df.loc[25:50]

# %%
df.sort_values(by="Calories")

# %%
df.sort_values(by="Calories",ascending=False)

# %%
df.isna().sum()

# %%
# Filtering my table based on conditions

condition1 = df["Calories"] < 100
condition2 = df["Caffeine (mg)"] < 50

df[condition1]

# %%
df[condition2]

# %%
# How about low calorie AND low caffeine drinks?

df[condition1 & condition2]

# %%
# Use categorical data to GROUP

# %%
df.groupby("Beverage_category")["Calories"].mean()

# %%
df.groupby("Beverage")["Calories"].mean()

# %%
df.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        'Total Fat (g)', 'Trans Fat (g)', 'Saturated Fat (g)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Cholesterol (mg)', 'Dietary Fibre (g)',
#        'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)',
#        'Calcium (% DV)', 'Iron (% DV)', 'Caffeine (mg)'],
#       dtype='object')

# %%
df.corr(numeric_only=True)

# %%
df.corr(numeric_only=True).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_cdda1_row0_col0, #T_cdda1_row1_col1, #T_cdda1_row2_col2, #T_cdda1_row3_col3, #T_cdda1_row4_col4, #T_cdda1_row5_col5, #T_cdda1_row6_col6, #T_cdda1_row7_col7, #T_cdda1_row8_col8, #T_cdda1_row9_col9, #T_cdda1_row10_col10, #T_cdda1_row11_col11, #T_cdda1_row12_col12, #T_cdda1_row13_col13, #T_cdda1_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cdda1_row0_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_cdda1_row0_col2, #T_cdda1_row2_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_cdda1_row0_col3, #T_cdda1_row1_col8, #T_cdda1_row6_col1, #T_cdda1_row12_col13 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_cdda1_row0_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_cdda1_row0_col5, #T_cdda1_row5_col6, #T_cdda1_row5_col8 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_cdda1_row0_col6 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# ...
